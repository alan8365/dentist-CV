# %%
from pathlib import Path

root = Path('./runs/detect/predict4/crops')
dist_root = Path('./dataset')

# %%
a = root.glob('**/*.jpg')
a = list(a)

a
# Out:
# [PosixPath('runs/detect/predict4/crops/32/201806270306345748_000054.jpg'),
#  PosixPath('runs/detect/predict4/crops/32/202011210511185181760_0590524A2.jpg'),
#  PosixPath('runs/detect/predict4/crops/32/00008510.jpg'),
#  PosixPath('runs/detect/predict4/crops/32/202011230311528421779_0580622A.jpg'),
#  PosixPath('runs/detect/predict4/crops/32/00008538.jpg'),
#  PosixPath('runs/detect/predict4/crops/32/2018062906062093143_000090.jpg'),
#  PosixPath('runs/detect/predict4/crops/32/201806281006247152_0000682.jpg'),
#  PosixPath('runs/detect/predict4/crops/32/202011170411257931674_0701103A.jpg'),
#  PosixPath('runs/detect/predict4/crops/32/202011300411548971910_0850101A.jpg'),
#  PosixPath('runs/detect/predict4/crops/32/202011130611547491606_0750627A.jpg'),
#  PosixPath('runs/detect/predict4/crops/32/00008464.jpg'),
#  PosixPath('runs/detect/predict4/crops/32/201808060608435832215_000581.jpg'),
#  PosixPath('runs/detect/predict4/crops/32/201807270707134881682_000486.jpg'),
# ...

# %%
for src in a:
    filename = src.stem
    tooth_number = 123

    new_filename = '-'.join(str(src))
    dist = dist_root / new_filename

    print(filename)
    break
# Out:
# 201806270306345748_000054
